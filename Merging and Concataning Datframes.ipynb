# %%
import pandas as pd

# %%
df_movies = pd.read_csv('IMDb movies.csv',low_memory=False)

# %%
df_ratings = pd.read_csv('IMDb ratings.csv')

# %%
df_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df_ratings.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
df_movies = df_movies[['imdb_title_id','title','year','genre','country']]
df_ratings = df_ratings[['imdb_title_id','total_votes','mean_vote']]

# %%
df_ratings
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0         tt0000009          154        5.9
# 1         tt0000574          589        6.3
# 2         tt0001892          188        6.0
# 3         tt0002101          446        5.3
# 4         tt0002130         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
df_movies
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
# [85855 rows x 5 columns]

# %% [markdown]
# ## Concatenate

# %% [markdown]
# ### concat()

# %%
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})
df2 = pd.DataFrame({'id': ['E','F','G','F'],
                    'age':[40,21,19,24]})

# %%
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2
# Out:
#   id  age
# 0  E   40
# 1  F   21
# 2  G   19
# 3  F   24

# %%
pd.concat([df1,df2],axis = 0,ignore_index=True)
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22
# 4  E   40
# 5  F   21
# 6  G   19
# 7  F   24

# %%
df_sample = df_movies.sample(frac=0.5)

# %%
df_sample.shape
# Out:
# (42928, 5)

# %%
df_concat_v = pd.concat([df_movies,df_sample],axis=0,ignore_index=True)
df_concat_v.shape
# Out:
# (128783, 5)

# %%
df_concat_v
# Out:
#        imdb_title_id                         title  year  \
# 0          tt0000009                    Miss Jerry  1894
# 1          tt0000574   The Story of the Kelly Gang  1906
# 2          tt0001892                Den sorte drøm  1911
# 3          tt0002101                     Cleopatra  1912
# 4          tt0002130                     L'Inferno  1911
# ...              ...                           ...   ...
# 128778     tt0155944                      Paranoia  1998
# 128779     tt2091935                     Mr. Right  2015
# 128780     tt1514446  Third Person Singular Number  2009
# 128781     tt2542616                   Miss Zombie  2013
# 128782     tt4126476                         After  2019
#
#                             genre           country
# 0                         Romance               USA
# 1         Biography, Crime, Drama         Australia
# 2                           Drama  Germany, Denmark
# 3                  Drama, History               USA
# 4       Adventure, Drama, Fantasy             Italy
# ...                           ...               ...
# 128778            Drama, Thriller               USA
# 128779    Action, Comedy, Romance               USA
# 128780                      Drama        Bangladesh
# 128781                     Horror             Japan
# 128782             Drama, Romance               USA
#
# [128783 rows x 5 columns]

# %% [markdown]
# ### Concatenate Horizontally

# %%
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})

# %%
df2 = pd.DataFrame({'job': ['Doctor','Engineer','Accountant','Developer']})

# %%
df_new = pd.concat([df1,df2],axis=1)

# %%
df_new.shape
# Out:
# (4, 3)

# %%
df_new
# Out:
#   id  age         job
# 0  A   30      Doctor
# 1  B   23    Engineer
# 2  C   25  Accountant
# 3  D   22   Developer

# %%
df_ratings.set_index('imdb_title_id',inplace=True)
df_movies.set_index('imdb_title_id',inplace=True)

# %%
df_concat_h = pd.concat([df_movies,df_ratings],axis=1)
df_concat_h.shape
df_concat_h
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# tt0002101                 Drama, History               USA          446
# tt0002130      Adventure, Drama, Fantasy             Italy         2237
# ...                                  ...               ...          ...
# tt9908390                         Comedy   France, Belgium          398
# tt9911196                  Comedy, Drama       Netherlands          724
# tt9911774                          Drama             India          265
# tt9914286                  Drama, Family            Turkey          194
# tt9914942                          Drama             Spain          102
#
#                mean_vote
# imdb_title_id
# tt0000009            5.9
# tt0000574            6.3
# tt0001892            6.0
# tt0002101            5.3
# tt0002130            6.9
# ...                  ...
# tt9908390            5.5
# tt9911196            7.9
# tt9911774            7.8
# tt9914286            9.4
# tt9914942            6.8
#
# [85855 rows x 6 columns]

# %%
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})

# %%
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2
# Out:
#   id           job
# 0  C        Doctor
# 1  D  Statistician
# 2  E    Accountant
# 3  F     Developer

# %% [markdown]
# ## Joins

# %% [markdown]
# ### Inner Joins

# %%
df_inner_join = df1.merge(df2,on='id',how='inner')

# %%
print(df1.shape)
print(df2.shape)
print(df_inner_join.shape)
df_inner_join
# Out:
# (4, 2)
# (4, 2)
# (2, 3)
#   id  age           job
# 0  C   25        Doctor
# 1  D   22  Statistician

# %%
## Exercise:
df_movies.merge(df_ratings,on='imdb_title_id',how='inner')

pd.merge(df_movies,df_ratings,on='imdb_title_id')
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# tt0002101                 Drama, History               USA          446
# tt0002130      Adventure, Drama, Fantasy             Italy         2237
# ...                                  ...               ...          ...
# tt9908390                         Comedy   France, Belgium          398
# tt9911196                  Comedy, Drama       Netherlands          724
# tt9911774                          Drama             India          265
# tt9914286                  Drama, Family            Turkey          194
# tt9914942                          Drama             Spain          102
#
#                mean_vote
# imdb_title_id
# tt0000009            5.9
# tt0000574            6.3
# tt0001892            6.0
# tt0002101            5.3
# tt0002130            6.9
# ...                  ...
# tt9908390            5.5
# tt9911196            7.9
# tt9911774            7.8
# tt9914286            9.4
# tt9914942            6.8
#
# [85855 rows x 6 columns]

# %% [markdown]
# ### FULL Joins/Outer Join

# %%
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})

# %%
df1.merge(df2,on='id',how='outer')
# Out:
#   id   age           job
# 0  A  30.0           NaN
# 1  B  23.0           NaN
# 2  C  25.0        Doctor
# 3  D  22.0  Statistician
# 4  E   NaN    Accountant
# 5  F   NaN     Developer

# %%
df1.merge(df2,on='id',how='outer').shape
# Out:
# (6, 3)

# %%
df_movies
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country
# imdb_title_id
# tt0000009                        Romance               USA
# tt0000574        Biography, Crime, Drama         Australia
# tt0001892                          Drama  Germany, Denmark
# tt0002101                 Drama, History               USA
# tt0002130      Adventure, Drama, Fantasy             Italy
# ...                                  ...               ...
# tt9908390                         Comedy   France, Belgium
# tt9911196                  Comedy, Drama       Netherlands
# tt9911774                          Drama             India
# tt9914286                  Drama, Family            Turkey
# tt9914942                          Drama             Spain
#
# [85855 rows x 4 columns]

# %%
## Exercise:
df_movies.merge(df_ratings,on='imdb_title_id',how='outer')
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# tt0002101                 Drama, History               USA          446
# tt0002130      Adventure, Drama, Fantasy             Italy         2237
# ...                                  ...               ...          ...
# tt9908390                         Comedy   France, Belgium          398
# tt9911196                  Comedy, Drama       Netherlands          724
# tt9911774                          Drama             India          265
# tt9914286                  Drama, Family            Turkey          194
# tt9914942                          Drama             Spain          102
#
#                mean_vote
# imdb_title_id
# tt0000009            5.9
# tt0000574            6.3
# tt0001892            6.0
# tt0002101            5.3
# tt0002130            6.9
# ...                  ...
# tt9908390            5.5
# tt9911196            7.9
# tt9911774            7.8
# tt9914286            9.4
# tt9914942            6.8
#
# [85855 rows x 6 columns]

# %% [markdown]
# ### Exclusive Full Joins

# %%
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})

# %%
df1.merge(df2,on='id',how='outer',indicator=True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df1.merge(df2,on='id',how='outer',indicator=True).query("_merge == 'left_only' or _merge == 'right_only'")
# Out:
#   id   age         job      _merge
# 0  A  30.0         NaN   left_only
# 1  B  23.0         NaN   left_only
# 4  E   NaN  Accountant  right_only
# 5  F   NaN   Developer  right_only

# %%
df1.merge(df2,on='id',how='outer',indicator=True).query("_merge == 'left_only' or _merge == 'right_only'")
# Out:
#   id   age         job      _merge
# 0  A  30.0         NaN   left_only
# 1  B  23.0         NaN   left_only
# 4  E   NaN  Accountant  right_only
# 5  F   NaN   Developer  right_only

# %%
df_movies.merge(df_ratings,on='imdb_title_id',how='outer',indicator=True).query("_merge!='both'")
# Out:
# Empty DataFrame
# Columns: [title, year, genre, country, total_votes, mean_vote, _merge]
# Index: []

# %% [markdown]
# ### Left Join

# %%
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})

# %%
df1.merge(df2,on='id',how='left')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician

# %%
df_sample = df_movies.sample(frac=0.5)

# %%
df_left = df_sample.merge(df_ratings,on='imdb_title_id',how='left')

# %%
df_left.shape
# Out:
# (42928, 6)

# %% [markdown]
# ### Exclusive Left Join

# %%
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})

# %%
df1.merge(df2,on='id',how='outer',indicator=True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df1.merge(df2,on='id',how='outer',indicator=True).query("_merge=='left_only'")
# Out:
#   id   age  job     _merge
# 0  A  30.0  NaN  left_only
# 1  B  23.0  NaN  left_only

# %%
df_movies_2 = df_movies.copy()

# %%
# keep the same loopy style but modify the COLUMN, not the index
for pos, idx in enumerate(df_movies_2.index):
    if pos < 1000:
        df_movies_2.loc[idx, 'imdb_title_id'] = 'tt1234567890'

# %%
df_movies_2
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country imdb_title_id
# imdb_title_id
# tt0000009                        Romance               USA  tt1234567890
# tt0000574        Biography, Crime, Drama         Australia  tt1234567890
# tt0001892                          Drama  Germany, Denmark  tt1234567890
# tt0002101                 Drama, History               USA  tt1234567890
# tt0002130      Adventure, Drama, Fantasy             Italy  tt1234567890
# ...                                  ...               ...           ...
# tt9908390                         Comedy   France, Belgium           NaN
# tt9911196                  Comedy, Drama       Netherlands           NaN
# tt9911774                          Drama             India           NaN
# tt9914286                  Drama, Family            Turkey           NaN
# tt9914942                          Drama             Spain           NaN
#
# [85855 rows x 5 columns]

# %%
df_exclusive_left = (
    df_movies_2
      .merge(df_ratings, left_on='imdb_title_id', right_index=True,
             how='outer', indicator=True)
      .query("_merge == 'left_only'")
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19568\928853565.py in ?()
#       1 df_exclusive_left = (
# ----> 2     df_movies_2
#       3       .merge(df_ratings, left_on='imdb_title_id', right_index=True,
#       4              how='outer', indicator=True)
#       5       .query("_merge == 'left_only'")
#
# c:\Users\priya\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10835         validate: MergeValidate | None = None,
#   10836     ) -> DataFrame:
#   10837         from pandas.core.reshape.merge import merge
#   10838
# > 10839         return merge(
#   10840             self,
#   10841             right,
#   10842             how=how,
#
# c:\Users\priya\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\priya\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\priya\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1324                 else:
#    1325                     # Then we're either Hashable or a wrong-length arraylike,
#    1326                     #  the latter of which will raise
#    1327                     k = cast(Hashable, k)
# -> 1328                     left_keys.append(left._get_label_or_level_values(k))
#    1329                     join_names.append(k)
#    1330             if isinstance(self.right.index, MultiIndex):
#    1331                 right_keys = [
#
# c:\Users\priya\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1902         axis = self._get_axis_number(axis)
#    1903         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1904
#    1905         if self._is_label_reference(key, axis=axis):
# -> 1906             self._check_label_or_level_ambiguity(key, axis=axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#
# c:\Users\priya\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1864             msg = (
#    1865                 f"'{key}' is both {level_article} {level_type} level and "
#    1866                 f"{label_article} {label_type} label, which is ambiguous."
#    1867             )
# -> 1868             raise ValueError(msg)
#
# ValueError: 'imdb_title_id' is both an index level and a column label, which is ambiguous.

# %%
## Not able to make exclusive left join as it is creating multiple same index columns
# Need help in this

# %%
print(df_movies_2.shape)
print(df_ratings.shape)
print(df_xclusive_left.shape)
# Out:
# (85855, 5)
# (85855, 2)
# (85855, 8)

# %% [markdown]
# ## Right Joins

# %%
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})

# %%
df1.merge(df2,on='id',how='right')
# Out:
#   id   age           job
# 0  C  25.0        Doctor
# 1  D  22.0  Statistician
# 2  E   NaN    Accountant
# 3  F   NaN     Developer

# %% [markdown]
# ### Exercise

# %%
df_movies = pd.read_csv('IMDb movies.csv',low_memory=False)

# %%
df_ratings = pd.read_csv('IMDb ratings.csv')

# %%
df_movies = df_movies[['imdb_title_id','title','year','genre','country']]
df_ratings = df_ratings[['imdb_title_id','total_votes','mean_vote']]

# %%
df_ratings_sample = df_ratings.sample(frac=0.3)

# %%
df_right = df_movies.merge(df_ratings_sample,on = 'imdb_title_id',how = 'right')

# %%
print(df_movies.shape)
print(df_ratings_sample.shape)
print(df_right.shape)
# Out:
# (85855, 5)
# (25756, 3)
# (25756, 7)

# %% [markdown]
# ## Exclusive Right Join

# %%
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job': ['Doctor','Statistician','Accountant','Developer']})
df1 = pd.DataFrame({'id': ['A','B','C','D'],
                    'age':[30,23,25,22]})

# %%
df1.merge(df2,on = 'id',how='outer',indicator=True).query("_merge == 'right_only'")
# Out:
#   id  age         job      _merge
# 4  E  NaN  Accountant  right_only
# 5  F  NaN   Developer  right_only

# %% [markdown]
# ### Exercise

# %%
df_ratings_copy = df_ratings.copy()

# %%
changed = (df_ratings_copy.loc[df_ratings_copy.index[:1000], 'imdb_title_id'] == 'tt1234567890').all()

# %%
new_df = df_movies.merge(df_ratings_copy,on='imdb_title_id',how='outer',indicator=True)

# %%
print(df_movies.shape)
print(df_ratings_copy.shape)
print(new_df.shape)
# Out:
# (85855, 5)
# (85855, 3)
# (85855, 8)

# %%
df_ratings_2 = df_ratings.copy()

# %%
for index in df_ratings_2.index:
    if index<1000:
        df_ratings_2.loc[index,'imdb_title_id'] = 'tt1234567890'

# %%
df_ratings_2
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0      tt1234567890          154        5.9
# 1      tt1234567890          589        6.3
# 2      tt1234567890          188        6.0
# 3      tt1234567890          446        5.3
# 4      tt1234567890         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
df_right_exclusive = df_movies.merge(df_ratings_2,on = 'imdb_title_id',how='outer',indicator=True).query("_merge == 'right_only'")

# %%
print(df_movies.shape)
print(df_ratings_copy.shape)
print(df_right_exclusive.shape)
# Out:
# (85855, 5)
# (85855, 3)
# (1000, 8)
