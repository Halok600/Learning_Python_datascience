# %% [markdown]
# ## Filter DataFrame based on condition

# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv',encoding="ISO-8859-1")
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
df_laptops['Company'] == 'Apple'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops[df_laptops['Company']=='Apple']
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 7             8   Apple  Macbook Air  Ultrabook    13.3
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 34           35   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# 794         803   Apple  MacBook 12"  Ultrabook    12.0
# 1069       1084   Apple  MacBook 12"  Ultrabook    12.0
# 1193       1211   Apple  MacBook 12"  Ultrabook    12.0
# 1210       1228   Apple  MacBook 12"  Ultrabook    12.0
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6
#
#                         ScreenResolution                     Cpu   Ram  \
# 0     IPS Panel Retina Display 2560x1600    Intel Core i5 2.3GHz   8GB
# 1                               1440x900    Intel Core i5 1.8GHz   8GB
# 3     IPS Panel Retina Display 2880x1800    Intel Core i7 2.7GHz  16GB
# 4     IPS Panel Retina Display 2560x1600    Intel Core i5 3.1GHz   8GB
# 6     IPS Panel Retina Display 2880x1800    Intel Core i7 2.2GHz  16GB
# 7                               1440x900    Intel Core i5 1.8GHz   8GB
# 12    IPS Panel Retina Display 2880x1800    Intel Core i7 2.8GHz  16GB
# 14    IPS Panel Retina Display 2304x1440  Intel Core M m3 1.2GHz   8GB
# 15    IPS Panel Retina Display 2560x1600    Intel Core i5 2.3GHz   8GB
# 17    IPS Panel Retina Display 2880x1800    Intel Core i7 2.9GHz  16GB
# 26                              1440x900    Intel Core i5 1.6GHz   8GB
# 34                              1440x900    Intel Core i5 1.6GHz   8GB
# 45    IPS Panel Retina Display 2560x1600    Intel Core i5 2.0GHz   8GB
# 81    IPS Panel Retina Display 2304x1440    Intel Core i5 1.3GHz   8GB
# 249   IPS Panel Retina Display 2560x1600    Intel Core i5 3.1GHz   8GB
# 270   IPS Panel Retina Display 2560x1600    Intel Core i5 2.9GHz   8GB
# 794   IPS Panel Retina Display 2304x1440     Intel Core M 1.2GHz   8GB
# 1069  IPS Panel Retina Display 2304x1440     Intel Core M 1.1GHz   8GB
# 1193  IPS Panel Retina Display 2304x1440     Intel Core M 1.1GHz   8GB
# 1210  IPS Panel Retina Display 2304x1440     Intel Core M 1.2GHz   8GB
# 1234                            1366x768    Intel Core i5 1.6GHz   4GB
#
#                    Memory                           Gpu     OpSys   Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640     macOS   1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000     macOS   1.34kg
# 3               512GB SSD            AMD Radeon Pro 455     macOS   1.83kg
# 4               256GB SSD  Intel Iris Plus Graphics 650     macOS   1.37kg
# 6     256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X   2.04kg
# 7     256GB Flash Storage        Intel HD Graphics 6000     macOS   1.34kg
# 12              256GB SSD            AMD Radeon Pro 555     macOS   1.83kg
# 14              256GB SSD         Intel HD Graphics 615     macOS   0.92kg
# 15              256GB SSD  Intel Iris Plus Graphics 640     macOS   1.37kg
# 17              512GB SSD            AMD Radeon Pro 560     macOS   1.83kg
# 26    128GB Flash Storage        Intel HD Graphics 6000  Mac OS X   1.35kg
# 34    256GB Flash Storage        Intel HD Graphics 6000  Mac OS X   1.35kg
# 45              256GB SSD       Intel Iris Graphics 540     macOS   1.37kg
# 81              512GB SSD         Intel HD Graphics 615     macOS   0.92kg
# 249             512GB SSD  Intel Iris Plus Graphics 650     macOS   1.37kg
# 270             512GB SSD       Intel Iris Graphics 550     macOS   1.37kg
# 794   512GB Flash Storage        Intel HD Graphics 5300  Mac OS X  0.920kg
# 1069  256GB Flash Storage         Intel HD Graphics 515  Mac OS X  0.920kg
# 1193  256GB Flash Storage        Intel HD Graphics 5300  Mac OS X  0.920kg
# 1210  512GB Flash Storage         Intel HD Graphics 515  Mac OS X  0.920kg
# 1234  256GB Flash Storage        Intel HD Graphics 6000  Mac OS X   1.08kg
#
#       Price_euros
# 0         1339.69
# 1          898.94
# 3         2537.45
# 4         1803.60
# 6         2139.97
# 7         1158.70
# 12        2439.97
# 14        1262.40
# 15        1518.55
# 17        2858.00
# 26        1099.00
# 34         998.00
# 45        1419.00
# 81        1510.00
# 249       2040.00
# 270       1958.90
# 794       1165.00
# 1069      1300.00
# 1193      1163.00
# 1210      1279.00
# 1234       959.00

# %%
df_laptops[df_laptops['Company']=='Apple'].value_counts('Company')
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Company']!='HP']
# Out:
#       laptop_ID Company                                    Product  \
# 0             1   Apple                                MacBook Pro
# 1             2   Apple                                Macbook Air
# 3             4   Apple                                MacBook Pro
# 4             5   Apple                                MacBook Pro
# 5             6    Acer                                   Aspire 3
# ...         ...     ...                                        ...
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       1316  Lenovo                             Yoga 500-14ISK
# 1299       1317  Lenovo                             Yoga 900-13ISK
# 1300       1318  Lenovo                         IdeaPad 100S-14IBR
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 5               Notebook    15.6                                    1366x768
# ...                  ...     ...                                         ...
# 1297            Notebook    15.6                                    1366x768
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# 5                  AMD A9-Series 9420 3GHz   4GB            500GB HDD
# ...                                    ...   ...                  ...
# 1297            Intel Core i7 6500U 2.5GHz   4GB            500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# 5                    AMD Radeon R5  Windows 10   2.1kg       400.00
# ...                            ...         ...     ...          ...
# 1297           Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1029 rows x 13 columns]

# %%
df_laptops[df_laptops['Company']!='HP'].value_counts('Company')
# Out:
# Company
# Lenovo       297
# Dell         297
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Google         3
# LG             3
# Fujitsu        3
# Huawei         2
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Price_euros']>2000]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# 12           13   Apple    MacBook Pro  Ultrabook    15.4
# 17           18   Apple    MacBook Pro  Ultrabook    15.4
# 58           59     MSI     GS73VR 7RG     Gaming    17.3
# ...         ...     ...            ...        ...     ...
# 1203       1221    Dell         XPS 13  Ultrabook    13.3
# 1209       1227    Asus      Rog Strix     Gaming    15.6
# 1231       1249   Razer      Blade Pro     Gaming    14.0
# 1236       1254      HP  EliteBook 840  Ultrabook    14.0
# 1247       1265    Asus    Rog GL502VS     Gaming    15.6
#
#                         ScreenResolution                          Cpu   Ram  \
# 3     IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# 6     IPS Panel Retina Display 2880x1800         Intel Core i7 2.2GHz  16GB
# 12    IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 17    IPS Panel Retina Display 2880x1800         Intel Core i7 2.9GHz  16GB
# 58                     Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# ...                                  ...                          ...   ...
# 1203    Quad HD+ / Touchscreen 3200x1800   Intel Core i7 7500U 2.7GHz  16GB
# 1209                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 1231                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 1236                           2560x1440   Intel Core i7 6500U 2.5GHz   8GB
# 1247         IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  16GB
#
#                     Memory                      Gpu       OpSys  Weight  \
# 3                512GB SSD       AMD Radeon Pro 455       macOS  1.83kg
# 6      256GB Flash Storage  Intel Iris Pro Graphics    Mac OS X  2.04kg
# 12               256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 17               512GB SSD       AMD Radeon Pro 560       macOS  1.83kg
# 58    256GB SSD +  2TB HDD  Nvidia GeForce GTX 1070  Windows 10  2.43kg
# ...                    ...                      ...         ...     ...
# 1203             512GB SSD    Intel HD Graphics 620  Windows 10   1.2kg
# 1209  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10   2.2kg
# 1231               1TB SSD  Nvidia GeForce GTX 1060  Windows 10  1.95kg
# 1236             256GB SSD    Intel HD Graphics 520   Windows 7  1.54kg
# 1247  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10  2.34kg
#
#       Price_euros
# 3         2537.45
# 6         2139.97
# 12        2439.97
# 17        2858.00
# 58        2449.00
# ...           ...
# 1203      2680.00
# 1209      2449.00
# 1231      3499.00
# 1236      2198.19
# 1247      2325.00
#
# [137 rows x 13 columns]

# %% [markdown]
# ### Create a column based on 1 Conditions:
# np.where()

# %%
import numpy as np

# %%
np.where(df_laptops['Price_euros']>2000,'Expensive','Cheap')
# Out:
# array(['Cheap', 'Cheap', 'Cheap', ..., 'Cheap', 'Cheap', 'Cheap'],
#       dtype='<U9')

# %%
df_laptops['Price_Tier'] = np.where(df_laptops['Price_euros']>2000,'Expensive','Cheap')

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Price_Tier
# 0      1339.69      Cheap
# 1       898.94      Cheap
# 2       575.00      Cheap
# 3      2537.45  Expensive
# 4      1803.60      Cheap

# %%
df_laptops.value_counts('Price_Tier')
# Out:
# Price_Tier
# Cheap        1166
# Expensive     137
# Name: count, dtype: int64

# %% [markdown]
# Exercise

# %%
np.where(df_laptops['Inches']>15,'Big','Small')
# Out:
# array(['Small', 'Small', 'Big', ..., 'Small', 'Big', 'Big'], dtype='<U5')

# %%
df_laptops['Screen_size'] = np.where(df_laptops['Inches']>15,'Big','Small')
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Price_Tier Screen_size
# 0      1339.69      Cheap       Small
# 1       898.94      Cheap       Small
# 2       575.00      Cheap         Big
# 3      2537.45  Expensive         Big
# 4      1803.60      Cheap       Small

# %%
df_laptops.value_counts('Screen_size')
# Out:
# Screen_size
# Big      835
# Small    468
# Name: count, dtype: int64

# %% [markdown]
# ## Filter DataFrame based on multiple condition

# %%
(df_laptops['Company']=='Apple') & (df_laptops['Price_euros']>2000)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %% [markdown]
# # & operators

# %%
df_laptops[(df_laptops['Company']=='Apple') & (df_laptops['Price_euros']>2000)]
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 17   IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
# 249  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
#
#                   Memory                           Gpu     OpSys  Weight  \
# 3              512GB SSD            AMD Radeon Pro 455     macOS  1.83kg
# 6    256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X  2.04kg
# 12             256GB SSD            AMD Radeon Pro 555     macOS  1.83kg
# 17             512GB SSD            AMD Radeon Pro 560     macOS  1.83kg
# 249            512GB SSD  Intel Iris Plus Graphics 650     macOS  1.37kg
#
#      Price_euros Price_Tier Screen_size
# 3        2537.45  Expensive         Big
# 6        2139.97  Expensive         Big
# 12       2439.97  Expensive         Big
# 17       2858.00  Expensive         Big
# 249      2040.00  Expensive       Small

# %% [markdown]
# # OR | operators

# %%
df_laptops[(df_laptops['Company']=='Apple') | (df_laptops['Company']=='Dell')]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 0             1   Apple    MacBook Pro  Ultrabook    13.3
# 1             2   Apple    Macbook Air  Ultrabook    13.3
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 4             5   Apple    MacBook Pro  Ultrabook    13.3
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# ...         ...     ...            ...        ...     ...
# 1278       1296    Dell  Inspiron 3552   Notebook    15.6
# 1281       1299    Dell  Inspiron 3567   Notebook    15.6
# 1290       1308    Dell  Inspiron 3567   Notebook    15.6
# 1292       1310    Dell  Inspiron 3552   Notebook    15.6
# 1295       1313    Dell  Inspiron 3567   Notebook    15.6
#
#                         ScreenResolution  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 3     IPS Panel Retina Display 2880x1800
# 4     IPS Panel Retina Display 2560x1600
# 6     IPS Panel Retina Display 2880x1800
# ...                                  ...
# 1278                            1366x768
# 1281                            1366x768
# 1290                            1366x768
# 1292                            1366x768
# 1295                            1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# 6                     Intel Core i7 2.2GHz  16GB  256GB Flash Storage
# ...                                    ...   ...                  ...
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB            500GB HDD
# 1281            Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 1290            Intel Core i3 7100U 2.4GHz   6GB              1TB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB            500GB HDD
# 1295            Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# 6          Intel Iris Pro Graphics    Mac OS X  2.04kg      2139.97
# ...                            ...         ...     ...          ...
# 1278             Intel HD Graphics  Windows 10  2.20kg       379.00
# 1281            AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1290         Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1292             Intel HD Graphics  Windows 10  2.20kg       379.00
# 1295            AMD Radeon R5 M430       Linux   2.3kg       805.99
#
#      Price_Tier Screen_size
# 0         Cheap       Small
# 1         Cheap       Small
# 3     Expensive         Big
# 4         Cheap       Small
# 6     Expensive         Big
# ...         ...         ...
# 1278      Cheap         Big
# 1281      Cheap         Big
# 1290      Cheap         Big
# 1292      Cheap         Big
# 1295      Cheap         Big
#
# [318 rows x 15 columns]

# %%
df_laptops[(df_laptops['Company']=='Apple') | (df_laptops['Company']=='Dell')].value_counts('Company')
# Out:
# Company
# Dell     297
# Apple     21
# Name: count, dtype: int64

# %%
df_laptops[((df_laptops['Company']=='Apple') | (df_laptops['Company']=='Dell')) & (df_laptops['Price_euros']>2000)]
# Out:
#       laptop_ID Company          Product            TypeName  Inches  \
# 3             4   Apple      MacBook Pro           Ultrabook    15.4
# 6             7   Apple      MacBook Pro           Ultrabook    15.4
# 12           13   Apple      MacBook Pro           Ultrabook    15.4
# 17           18   Apple      MacBook Pro           Ultrabook    15.4
# 186         190    Dell           XPS 15            Notebook    15.6
# 204         208    Dell   Precision 7520         Workstation    15.6
# 224         229    Dell     Alienware 17              Gaming    17.3
# 249         254   Apple      MacBook Pro           Ultrabook    13.3
# 297         302    Dell   Precision 7720         Workstation    17.3
# 311         316    Dell           XPS 13           Ultrabook    13.3
# 329         335    Dell           XPS 15            Notebook    15.6
# 350         356    Dell           XPS 15            Notebook    15.6
# 388         394    Dell   Precision 5520         Workstation    15.6
# 398         405    Dell  Precision M5520         Workstation    15.6
# 424         431    Dell     Alienware 17              Gaming    17.3
# 456         463    Dell     Alienware 17            Notebook    17.3
# 476         483    Dell  Precision M5520         Workstation    15.6
# 486         493    Dell   Precision 3520         Workstation    15.6
# 530         537    Dell     Alienware 17              Gaming    17.3
# 552         559    Dell     Alienware 17              Gaming    17.3
# 639         647    Dell           XPS 15            Notebook    15.6
# 659         667    Dell     Alienware 17              Gaming    17.3
# 682         690    Dell     Alienware 15              Gaming    15.6
# 685         693    Dell     Alienware 15              Gaming    15.6
# 723         731    Dell     Alienware 17              Gaming    17.3
# 758         767    Dell     Alienware 17              Gaming    15.6
# 780         789    Dell     Alienware 17              Gaming    17.3
# 818         827    Dell     Alienware 17              Gaming    17.3
# 835         844    Dell     Alienware 15              Gaming    15.6
# 841         851    Dell     Alienware 17              Gaming    17.3
# 864         875    Dell           XPS 13           Ultrabook    13.3
# 900         912    Dell           XPS 13  2 in 1 Convertible    13.3
# 939         953    Dell     Alienware 17              Gaming    17.3
# 955         969    Dell     Alienware 17              Gaming    17.3
# 968         982    Dell     Alienware 17              Gaming    17.3
# 972         986    Dell     Alienware 17              Gaming    17.3
# 1054       1068    Dell           XPS 13           Ultrabook    13.3
# 1154       1172    Dell           XPS 15            Notebook    15.6
# 1203       1221    Dell           XPS 13           Ultrabook    13.3
#
#                                    ScreenResolution  \
# 3                IPS Panel Retina Display 2880x1800
# 6                IPS Panel Retina Display 2880x1800
# 12               IPS Panel Retina Display 2880x1800
# 17               IPS Panel Retina Display 2880x1800
# 186             4K Ultra HD / Touchscreen 3840x2160
# 204                           4K Ultra HD 3840x2160
# 224                     IPS Panel Full HD 1920x1080
# 249              IPS Panel Retina Display 2560x1600
# 297                               Full HD 1920x1080
# 311   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 329             4K Ultra HD / Touchscreen 3840x2160
# 350             4K Ultra HD / Touchscreen 3840x2160
# 388                     IPS Panel Full HD 1920x1080
# 398             4K Ultra HD / Touchscreen 3840x2160
# 424                             IPS Panel 2560x1440
# 456                     IPS Panel Full HD 1920x1080
# 476                               Full HD 1920x1080
# 486                     IPS Panel Full HD 1920x1080
# 530                     IPS Panel Full HD 1920x1080
# 552                     IPS Panel Full HD 1920x1080
# 639             4K Ultra HD / Touchscreen 3840x2160
# 659                 IPS Panel 4K Ultra HD 3840x2160
# 682                               Full HD 1920x1080
# 685                               Full HD 1920x1080
# 723                           4K Ultra HD 3840x2160
# 758                 IPS Panel 4K Ultra HD 3840x2160
# 780                     IPS Panel Full HD 1920x1080
# 818                     IPS Panel Full HD 1920x1080
# 835                               Full HD 1920x1080
# 841                     IPS Panel Full HD 1920x1080
# 864                Quad HD+ / Touchscreen 3200x1800
# 900                Quad HD+ / Touchscreen 3200x1800
# 939                                       2560x1440
# 955                 IPS Panel 4K Ultra HD 3840x2160
# 968                     IPS Panel Full HD 1920x1080
# 972                               Full HD 1920x1080
# 1054               Quad HD+ / Touchscreen 3200x1800
# 1154  IPS Panel Touchscreen / 4K Ultra HD 3840x2160
# 1203               Quad HD+ / Touchscreen 3200x1800
#
#                               Cpu   Ram                Memory  \
# 3            Intel Core i7 2.7GHz  16GB             512GB SSD
# 6            Intel Core i7 2.2GHz  16GB   256GB Flash Storage
# 12           Intel Core i7 2.8GHz  16GB             256GB SSD
# 17           Intel Core i7 2.9GHz  16GB             512GB SSD
# 186   Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 204   Intel Xeon E3-1505M V6 3GHz  16GB  256GB SSD +  1TB HDD
# 224   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 249          Intel Core i5 3.1GHz   8GB             512GB SSD
# 297   Intel Core i7 7820HQ 2.9GHz  16GB             256GB SSD
# 311    Intel Core i7 8550U 1.8GHz  16GB               1TB SSD
# 329   Intel Core i7 7700HQ 2.8GHz  32GB               1TB SSD
# 350   Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 388   Intel Core i7 6820HQ 2.7GHz   8GB             256GB SSD
# 398   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 424   Intel Core i7 7820HK 2.9GHz  16GB  256GB SSD +  1TB HDD
# 456   Intel Core i7 7700HQ 2.7GHz   8GB               1TB HDD
# 476   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 486   Intel Core i7 6820HQ 2.7GHz  16GB             512GB SSD
# 530   Intel Core i7 7700HQ 2.8GHz  16GB  128GB SSD +  1TB HDD
# 552   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 639   Intel Core i7 7700HQ 2.8GHz  16GB               1TB SSD
# 659   Intel Core i7 7700HQ 2.8GHz  32GB  512GB SSD +  1TB HDD
# 682   Intel Core i5 7300HQ 2.5GHz  16GB  128GB SSD +  1TB HDD
# 685   Intel Core i7 7820HK 2.9GHz  16GB  256GB SSD +  1TB HDD
# 723   Intel Core i7 7700HQ 2.8GHz  32GB    1TB SSD +  1TB HDD
# 758   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 780   Intel Core i7 7700HQ 2.8GHz  32GB    1TB SSD +  1TB HDD
# 818   Intel Core i7 7700HQ 2.8GHz  16GB  128GB SSD +  1TB HDD
# 835   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 841   Intel Core i7 7700HQ 2.8GHz  32GB  512GB SSD +  1TB HDD
# 864    Intel Core i7 7660U 2.5GHz  16GB             512GB SSD
# 900     Intel Core i7 7Y75 1.3GHz   8GB             512GB SSD
# 939   Intel Core i7 6820HK 2.7GHz  16GB  512GB SSD +  1TB HDD
# 955   Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 968   Intel Core i7 7700HQ 2.8GHz  32GB  256GB SSD +  1TB HDD
# 972   Intel Core i7 6700HQ 2.6GHz  32GB  256GB SSD +  1TB HDD
# 1054   Intel Core i7 7500U 2.7GHz  16GB               1TB SSD
# 1154  Intel Core i5 6300HQ 2.3GHz   8GB             256GB SSD
# 1203   Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 6          Intel Iris Pro Graphics    Mac OS X  2.04kg      2139.97
# 12              AMD Radeon Pro 555       macOS  1.83kg      2439.97
# 17              AMD Radeon Pro 560       macOS  1.83kg      2858.00
# 186        Nvidia GeForce GTX 1050  Windows 10  2.06kg      2397.00
# 204            Nvidia Quadro M1200  Windows 10   2.8kg      3055.00
# 224        Nvidia GeForce GTX 1060  Windows 10  4.42kg      2456.34
# 249   Intel Iris Plus Graphics 650       macOS  1.37kg      2040.00
# 297            Nvidia Quadro M1200  Windows 10  3.42kg      2884.86
# 311         Intel UHD Graphics 620  Windows 10  1.21kg      2499.00
# 329        Nvidia GeForce GTX 1050  Windows 10  2.06kg      2639.00
# 350        Nvidia GeForce GTX 1050  Windows 10  2.06kg      2027.42
# 388            Nvidia Quadro M1200  Windows 10     2kg      2135.00
# 398            Nvidia Quadro M1200  Windows 10  1.78kg      2712.00
# 424        Nvidia GeForce GTX 1070  Windows 10  4.42kg      2799.00
# 456        Nvidia GeForce GTX 1060  Windows 10  4.42kg      2046.00
# 476            Nvidia Quadro M1200  Windows 10  1.78kg      2408.00
# 486             Nvidia Quadro M620  Windows 10  2.17kg      2338.00
# 530        Nvidia GeForce GTX 1070  Windows 10  4.42kg      3012.77
# 552        Nvidia GeForce GTX 1070  Windows 10  4.42kg      2699.00
# 639        Nvidia GeForce GTX 1050  Windows 10  2.06kg      2399.00
# 659        Nvidia GeForce GTX 1070  Windows 10  4.42kg      3147.37
# 682        Nvidia GeForce GTX 1060  Windows 10  3.21kg      2051.00
# 685        Nvidia GeForce GTX 1070  Windows 10  3.49kg      2813.75
# 723        Nvidia GeForce GTX 1070  Windows 10  4.36kg      3659.40
# 758        Nvidia GeForce GTX 1070  Windows 10  4.42kg      2868.99
# 780       Nvidia GeForce GTX 1070M  Windows 10  4.42kg      3588.80
# 818        Nvidia GeForce GTX 1060  Windows 10  4.36kg      2505.02
# 835        Nvidia GeForce GTX 1070  Windows 10  3.21kg      2774.63
# 841        Nvidia GeForce GTX 1070  Windows 10  4.42kg      3072.89
# 864   Intel Iris Plus Graphics 640  Windows 10  1.29kg      2240.00
# 900          Intel HD Graphics 615  Windows 10  1.24kg      2013.10
# 939        Nvidia GeForce GTX 1080  Windows 10  4.36kg      2758.00
# 955        Nvidia GeForce GTX 1070  Windows 10  4.36kg      3154.00
# 968        Nvidia GeForce GTX 1070  Windows 10  4.42kg      3149.00
# 972        Nvidia GeForce GTX 1070  Windows 10  4.42kg      2800.00
# 1054         Intel HD Graphics 620  Windows 10   1.2kg      2254.00
# 1154           Nvidia GeForce 960M  Windows 10  2.04kg      2250.68
# 1203         Intel HD Graphics 620  Windows 10   1.2kg      2680.00
#
#      Price_Tier Screen_size
# 3     Expensive         Big
# 6     Expensive         Big
# 12    Expensive         Big
# 17    Expensive         Big
# 186   Expensive         Big
# 204   Expensive         Big
# 224   Expensive         Big
# 249   Expensive       Small
# 297   Expensive         Big
# 311   Expensive       Small
# 329   Expensive         Big
# 350   Expensive         Big
# 388   Expensive         Big
# 398   Expensive         Big
# 424   Expensive         Big
# 456   Expensive         Big
# 476   Expensive         Big
# 486   Expensive         Big
# 530   Expensive         Big
# 552   Expensive         Big
# 639   Expensive         Big
# 659   Expensive         Big
# 682   Expensive         Big
# 685   Expensive         Big
# 723   Expensive         Big
# 758   Expensive         Big
# 780   Expensive         Big
# 818   Expensive         Big
# 835   Expensive         Big
# 841   Expensive         Big
# 864   Expensive       Small
# 900   Expensive       Small
# 939   Expensive         Big
# 955   Expensive         Big
# 968   Expensive         Big
# 972   Expensive         Big
# 1054  Expensive       Small
# 1154  Expensive         Big
# 1203  Expensive       Small

# %% [markdown]
# ## Creating a Conditional Column from More than 2 Choices : np.select()

# %%
conditions = [
    df_laptops['Price_euros']>3000,
    (df_laptops['Price_euros']>2000) & (df_laptops['Price_euros']<=3000),
    (df_laptops['Price_euros']>800) & (df_laptops['Price_euros']<=2000),
    df_laptops['Price_euros']<=800
]

values = ['Too Expensive','Expensive','Affordable','Cheap']

# %%
df_laptops['Price_Tiers'] = np.select(conditions,values,default=None)
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
#      Price_Tier Screen_size Price_Tiers
# 0         Cheap       Small  Affordable
# 1         Cheap       Small  Affordable
# 2         Cheap         Big       Cheap
# 3     Expensive         Big   Expensive
# 4         Cheap       Small  Affordable
# ...         ...         ...         ...
# 1298      Cheap       Small       Cheap
# 1299      Cheap       Small  Affordable
# 1300      Cheap       Small       Cheap
# 1301      Cheap         Big       Cheap
# 1302      Cheap         Big       Cheap
#
# [1303 rows x 16 columns]

# %%
df_laptops['Price_Tiers'].value_counts()
# Out:
# Price_Tiers
# Affordable       655
# Cheap            511
# Expensive        118
# Too Expensive     19
# Name: count, dtype: int64

# %% [markdown]
# ## Exercises

# %%
cond1 = [
    df_laptops['Inches']>16,
    (df_laptops['Inches']>14) & (df_laptops['Inches']<=16),
    (df_laptops['Inches']>12) & (df_laptops['Inches']<=14),
    df_laptops['Inches']<=12
]

val1 = ['Too Big','Big','Small','Too Small']

# %%
df_laptops['Screen_Cat'] = np.select(cond1,val1,default=None)

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
#      Price_Tier Screen_size Price_Tiers Screen_Cat
# 0         Cheap       Small  Affordable      Small
# 1         Cheap       Small  Affordable      Small
# 2         Cheap         Big       Cheap        Big
# 3     Expensive         Big   Expensive        Big
# 4         Cheap       Small  Affordable      Small
# ...         ...         ...         ...        ...
# 1298      Cheap       Small       Cheap      Small
# 1299      Cheap       Small  Affordable      Small
# 1300      Cheap       Small       Cheap      Small
# 1301      Cheap         Big       Cheap        Big
# 1302      Cheap         Big       Cheap        Big
#
# [1303 rows x 17 columns]

# %%
df_laptops['Screen_Cat'].value_counts()
# Out:
# Screen_Cat
# Big          674
# Small        419
# Too Big      166
# Too Small     44
# Name: count, dtype: int64

# %% [markdown]
# ## isin(): Single Filtering

# %%
df_laptops['Company'].isin(['Apple','HP'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops[df_laptops['Company'].isin(['Apple','HP'])].value_counts('Company')
# Out:
# Company
# HP       274
# Apple     21
# Name: count, dtype: int64

# %% [markdown]
# ## isin(): Multiple Filtering

# %%
filter1 = df_laptops['TypeName'].isin(['Notebook','Ultrabook'])
filter2 = df_laptops['Company'].isin(['Apple','HP'])
filter1 & filter2
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Length: 1303, dtype: bool

# %%
df_laptops[filter1 & filter2].value_counts()
# Out:
# laptop_ID  Company  Product                              TypeName   Inches  ScreenResolution                    Cpu                         Ram   Memory               Gpu                           OpSys       Weight  Price_euros  Price_Tier  Screen_size  Price_Tiers  Screen_Cat
# 1          Apple    MacBook Pro                          Ultrabook  13.3    IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz        8GB   128GB SSD            Intel Iris Plus Graphics 640  macOS       1.37kg  1339.69      Cheap       Small        Affordable   Small         1
# 2          Apple    Macbook Air                          Ultrabook  13.3    1440x900                            Intel Core i5 1.8GHz        8GB   128GB Flash Storage  Intel HD Graphics 6000        macOS       1.34kg  898.94       Cheap       Small        Affordable   Small         1
# 3          HP       250 G6                               Notebook   15.6    Full HD 1920x1080                   Intel Core i5 7200U 2.5GHz  8GB   256GB SSD            Intel HD Graphics 620         No OS       1.86kg  575.00       Cheap       Big          Cheap        Big           1
# 4          Apple    MacBook Pro                          Ultrabook  15.4    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz        16GB  512GB SSD            AMD Radeon Pro 455            macOS       1.83kg  2537.45      Expensive   Big          Expensive    Big           1
# 5          Apple    MacBook Pro                          Ultrabook  13.3    IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz        8GB   256GB SSD            Intel Iris Plus Graphics 650  macOS       1.37kg  1803.60      Cheap       Small        Affordable   Small         1
#                                                                                                                                                                                                                                                                                          ..
# 1291       HP       15-AC110nv (i7-6500U/6GB/1TB/Radeon  Notebook   15.6    1366x768                            Intel Core i7 6500U 2.5GHz  6GB   1TB HDD              AMD Radeon R5 M330            Windows 10  2.19kg  764.00       Cheap       Big          Cheap        Big           1
# 1298       HP       Pavilion 15-AW003nv                  Notebook   15.6    Full HD 1920x1080                   AMD A9-Series 9410 2.9GHz   6GB   1.0TB Hybrid         AMD Radeon R7 M440            Windows 10  2.04kg  549.99       Cheap       Big          Cheap        Big           1
# 1305       HP       15-AC110nv (i7-6500U/6GB/1TB/Radeon  Notebook   15.6    1366x768                            Intel Core i7 6500U 2.5GHz  6GB   1TB HDD              AMD Radeon R5 M330            Windows 10  2.19kg  764.00       Cheap       Big          Cheap        Big           1
# 1312       HP       Pavilion 15-AW003nv                  Notebook   15.6    Full HD 1920x1080                   AMD A9-Series 9410 2.9GHz   6GB   1.0TB Hybrid         AMD Radeon R7 M440            Windows 10  2.04kg  549.99       Cheap       Big          Cheap        Big           1
# 1319       HP       15-AC110nv (i7-6500U/6GB/1TB/Radeon  Notebook   15.6    1366x768                            Intel Core i7 6500U 2.5GHz  6GB   1TB HDD              AMD Radeon R5 M330            Windows 10  2.19kg  764.00       Cheap       Big          Cheap        Big           1
# Name: count, Length: 241, dtype: int64

# %% [markdown]
# ## Duplicated()

# %% [markdown]
# ### Example 1

# %%
df_laptops.duplicated('laptop_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price_Tier, Screen_size, Price_Tiers, Screen_Cat]
# Index: []

# %%
df_laptops.duplicated(['Product','TypeName','Inches'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
duplicated = df_laptops.duplicated(['Product','TypeName','Inches'])

# %%
df_laptops[duplicated].sort_values(['Product','TypeName'])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# 1098            Notebook    15.6                                   1366x768
# 1170            Notebook    15.6                          Full HD 1920x1080
# 10              Notebook    15.6                                   1366x768
# ...                  ...     ...                                        ...
# 414   2 in 1 Convertible    13.3  IPS Panel Full HD / Touchscreen 1920x1080
# 826   2 in 1 Convertible    13.3            Touchscreen / Full HD 1920x1080
# 1275           Ultrabook    13.3                IPS Panel Full HD 1920x1080
# 1289           Ultrabook    13.3                IPS Panel Full HD 1920x1080
# 676            Ultrabook    14.0                          Full HD 1920x1080
#
#                                        Cpu  Ram     Memory  \
# 1287            Intel Core i7 6500U 2.5GHz  6GB    1TB HDD
# 1301            Intel Core i7 6500U 2.5GHz  6GB    1TB HDD
# 1098  Intel Pentium Quad Core N3710 1.6GHz  4GB    1TB HDD
# 1170            Intel Core i7 6500U 2.5GHz  8GB  256GB SSD
# 10              Intel Core i5 7200U 2.5GHz  4GB  500GB HDD
# ...                                    ...  ...        ...
# 414             Intel Core i5 7200U 2.5GHz  8GB  256GB SSD
# 826             Intel Core i5 7200U 2.5GHz  8GB  256GB SSD
# 1275              Intel Core M 6Y30 0.9GHz  8GB  512GB SSD
# 1289              Intel Core M 6Y30 0.9GHz  8GB  512GB SSD
# 676             Intel Core i5 7200U 2.5GHz  8GB  256GB SSD
#
#                         Gpu       OpSys  Weight  Price_euros Price_Tier  \
# 1287     AMD Radeon R5 M330  Windows 10  2.19kg        764.0      Cheap
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg        764.0      Cheap
# 1098  Intel HD Graphics 405  Windows 10  1.96kg        500.0      Cheap
# 1170  Intel HD Graphics 520  Windows 10  1.96kg        679.0      Cheap
# 10    Intel HD Graphics 620       No OS  1.86kg        393.9      Cheap
# ...                     ...         ...     ...          ...        ...
# 414   Intel HD Graphics 620  Windows 10  1.27kg        928.0      Cheap
# 826   Intel HD Graphics 620  Windows 10   1.1kg       1358.0      Cheap
# 1275  Intel HD Graphics 515  Windows 10   1.2kg        729.0      Cheap
# 1289  Intel HD Graphics 515  Windows 10   1.2kg        729.0      Cheap
# 676   Intel HD Graphics 620  Windows 10   1.1kg       1135.0      Cheap
#
#      Screen_size Price_Tiers Screen_Cat
# 1287         Big       Cheap        Big
# 1301         Big       Cheap        Big
# 1098         Big       Cheap        Big
# 1170         Big       Cheap        Big
# 10           Big       Cheap        Big
# ...          ...         ...        ...
# 414        Small  Affordable      Small
# 826        Small  Affordable      Small
# 1275       Small       Cheap      Small
# 1289       Small       Cheap      Small
# 676        Small  Affordable      Small
#
# [620 rows x 17 columns]

# %%
df_laptops = df_laptops.sort_values(['Company','Price_euros'])
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram  \
# 1215                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 290                      1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 1102                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   4GB
# 695                      1366x768  Intel Celeron Dual Core N3050 1.6GHz   4GB
# 1198                     1366x768    Intel Celeron Dual Core N3350 2GHz   4GB
# ...                           ...                                   ...   ...
# 191   IPS Panel Full HD 1920x1080  Intel Celeron Dual Core N3350 1.1GHz   4GB
# 877   IPS Panel Full HD 1920x1080            Intel Core i5 6200U 2.3GHz   8GB
# 192   IPS Panel Full HD 1920x1080            Intel Core i5 7200U 2.5GHz   8GB
# 184   IPS Panel Full HD 1920x1080            Intel Core i5 8250U 1.6GHz   8GB
# 514   IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz  16GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 1215            32GB SSD      Intel HD Graphics   Chrome OS   1.3kg
# 290             16GB SSD      Intel HD Graphics   Chrome OS  2.19kg
# 1102            16GB SSD      Intel HD Graphics   Chrome OS  2.20kg
# 695   32GB Flash Storage      Intel HD Graphics  Windows 10   1.4kg
# 1198             1TB HDD  Intel HD Graphics 500       Linux   2.1kg
# ...                  ...                    ...         ...     ...
# 191   32GB Flash Storage  Intel HD Graphics 500  Windows 10   1.3kg
# 877            256GB SSD   Nvidia GeForce 940MX  Windows 10  1.28kg
# 192            256GB SSD   Nvidia GeForce MX150       No OS   1.3kg
# 184            256GB SSD   Nvidia GeForce MX150       No OS  1.95kg
# 514            256GB SSD   Nvidia GeForce MX150       No OS  1.95kg
#
#       Price_euros Price_Tier Screen_size Price_Tiers Screen_Cat
# 1215       174.00      Cheap       Small       Cheap  Too Small
# 290        199.00      Cheap         Big       Cheap        Big
# 1102       209.00      Cheap         Big       Cheap        Big
# 695        269.00      Cheap       Small       Cheap  Too Small
# 1198       272.00      Cheap         Big       Cheap        Big
# ...           ...        ...         ...         ...        ...
# 191        260.00      Cheap       Small       Cheap      Small
# 877        935.00      Cheap       Small  Affordable      Small
# 192        999.90      Cheap       Small  Affordable      Small
# 184       1199.00      Cheap         Big  Affordable        Big
# 514       1399.95      Cheap         Big  Affordable        Big
#
# [1303 rows x 17 columns]

# %%
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
duplicated_first = df_laptops.duplicated('Company',keep = 'first')
#cheapest laptops of a company

# %%
df_laptops[duplicated_first]
# Out:
#       laptop_ID Company                        Product   TypeName  Inches  \
# 290         295    Acer           Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                  Chromebook 15   Notebook    15.6
# 695         703    Acer              TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                       Aspire 3   Notebook    15.6
# 1263       1281    Acer                 Aspire ES1-531   Notebook    15.6
# ...         ...     ...                            ...        ...     ...
# 1041       1055    Vero   V142 (X5-Z8350/2GB/32GB/W10)   Notebook    14.0
# 191         195    Vero  K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 192         196  Xiaomi                    Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                    Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                    Mi Notebook   Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram  \
# 290                      1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 1102                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   4GB
# 695                      1366x768  Intel Celeron Dual Core N3050 1.6GHz   4GB
# 1198                     1366x768    Intel Celeron Dual Core N3350 2GHz   4GB
# 1263                     1366x768  Intel Celeron Dual Core N3060 1.6GHz   4GB
# ...                           ...                                   ...   ...
# 1041                     1366x768           Intel Atom X5-Z8350 1.44GHz   2GB
# 191   IPS Panel Full HD 1920x1080  Intel Celeron Dual Core N3350 1.1GHz   4GB
# 192   IPS Panel Full HD 1920x1080            Intel Core i5 7200U 2.5GHz   8GB
# 184   IPS Panel Full HD 1920x1080            Intel Core i5 8250U 1.6GHz   8GB
# 514   IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz  16GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 290             16GB SSD      Intel HD Graphics   Chrome OS  2.19kg
# 1102            16GB SSD      Intel HD Graphics   Chrome OS  2.20kg
# 695   32GB Flash Storage      Intel HD Graphics  Windows 10   1.4kg
# 1198             1TB HDD  Intel HD Graphics 500       Linux   2.1kg
# 1263           500GB HDD  Intel HD Graphics 400       Linux   2.4kg
# ...                  ...                    ...         ...     ...
# 1041  32GB Flash Storage  Intel HD Graphics 400  Windows 10  1.45kg
# 191   32GB Flash Storage  Intel HD Graphics 500  Windows 10   1.3kg
# 192            256GB SSD   Nvidia GeForce MX150       No OS   1.3kg
# 184            256GB SSD   Nvidia GeForce MX150       No OS  1.95kg
# 514            256GB SSD   Nvidia GeForce MX150       No OS  1.95kg
#
#       Price_euros Price_Tier Screen_size Price_Tiers Screen_Cat
# 290        199.00      Cheap         Big       Cheap        Big
# 1102       209.00      Cheap         Big       Cheap        Big
# 695        269.00      Cheap       Small       Cheap  Too Small
# 1198       272.00      Cheap         Big       Cheap        Big
# 1263       289.00      Cheap         Big       Cheap        Big
# ...           ...        ...         ...         ...        ...
# 1041       210.80      Cheap       Small       Cheap      Small
# 191        260.00      Cheap       Small       Cheap      Small
# 192        999.90      Cheap       Small  Affordable      Small
# 184       1199.00      Cheap         Big  Affordable        Big
# 514       1399.95      Cheap         Big  Affordable        Big
#
# [1284 rows x 17 columns]

# %%
df_laptops[~duplicated_first][['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
df_laptops[~duplicated_first].value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
duplicared_last = df_laptops.duplicated('Company',keep = 'last')
#Most Expensive laptop of a company
duplicated_false = df_laptops.duplicated('Company',keep = False)

# %%
df_laptops[~duplicared_last][['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %%
df_laptops[~duplicated_false]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price_Tier, Screen_size, Price_Tiers, Screen_Cat]
# Index: []

# %%
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %% [markdown]
# ## Drop Duplicates

# %%
df_laptops = pd.read_csv('laptop_price.csv',encoding = 'ISO-8859-1')

# %%
df_laptops.drop_duplicates(['Company'])
# Out:
#      laptop_ID    Company                        Product            TypeName  \
# 0            1      Apple                    MacBook Pro           Ultrabook
# 2            3         HP                         250 G6            Notebook
# 5            6       Acer                       Aspire 3            Notebook
# 8            9       Asus                ZenBook UX430UN           Ultrabook
# 13          14       Dell                  Inspiron 3567            Notebook
# 18          19     Lenovo              IdeaPad 320-15IKB            Notebook
# 30          31      Chuwi                  LapBook 15.6"            Notebook
# 58          59        MSI                     GS73VR 7RG              Gaming
# 70          72  Microsoft                 Surface Laptop           Ultrabook
# 143        146    Toshiba                  Satellite Pro            Notebook
# 170        174     Huawei                     MateBook X           Ultrabook
# 184        188     Xiaomi                    Mi Notebook            Notebook
# 191        195       Vero  K147 (N3350/4GB/32GB/FHD/W10)            Notebook
# 196        200      Razer                      Blade Pro              Gaming
# 429        436   Mediacom                  FlexBook Edge  2 in 1 Convertible
# 430        437    Samsung                   Chromebook 3             Netbook
# 437        444     Google                Pixelbook (Core           Ultrabook
# 567        574    Fujitsu                  Lifebook A557            Notebook
# 678        686         LG                    Gram 15Z975           Ultrabook
#
#      Inches                           ScreenResolution  \
# 0      13.3         IPS Panel Retina Display 2560x1600
# 2      15.6                          Full HD 1920x1080
# 5      15.6                                   1366x768
# 8      14.0                          Full HD 1920x1080
# 13     15.6                          Full HD 1920x1080
# 18     15.6                          Full HD 1920x1080
# 30     15.6                          Full HD 1920x1080
# 58     17.3                          Full HD 1920x1080
# 70     13.5                      Touchscreen 2256x1504
# 143    15.6                                   1366x768
# 170    13.0                IPS Panel Full HD 2160x1440
# 184    15.6                IPS Panel Full HD 1920x1080
# 191    14.0                IPS Panel Full HD 1920x1080
# 196    17.3        4K Ultra HD / Touchscreen 3840x2160
# 429    11.6  IPS Panel Full HD / Touchscreen 1920x1080
# 430    11.6                                   1366x768
# 437    12.3                      Touchscreen 2400x1600
# 567    15.6                                   1366x768
# 678    15.6                IPS Panel Full HD 1920x1080
#
#                                       Cpu   Ram                Memory  \
# 0                    Intel Core i5 2.3GHz   8GB             128GB SSD
# 2              Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 5                 AMD A9-Series 9420 3GHz   4GB             500GB HDD
# 8              Intel Core i7 8550U 1.8GHz  16GB             512GB SSD
# 13               Intel Core i3 6006U 2GHz   4GB             256GB SSD
# 18             Intel Core i3 7100U 2.4GHz   8GB               1TB HDD
# 30            Intel Atom x5-Z8300 1.44GHz   4GB    64GB Flash Storage
# 58            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  2TB HDD
# 70             Intel Core i5 7200U 2.5GHz   4GB             128GB SSD
# 143            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 170            Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 184            Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 191  Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 196           Intel Core i7 7820HK 2.9GHz  32GB               1TB SSD
# 429  Intel Celeron Dual Core N3350 1.1GHz   4GB              32GB SSD
# 430  Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 437             Intel Core i7 7Y75 1.3GHz  16GB             512GB SSD
# 567            Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 678            Intel Core i7 8550U 1.8GHz   8GB             512GB SSD
#
#                               Gpu         OpSys   Weight  Price_euros
# 0    Intel Iris Plus Graphics 640         macOS   1.37kg      1339.69
# 2           Intel HD Graphics 620         No OS   1.86kg       575.00
# 5                   AMD Radeon R5    Windows 10    2.1kg       400.00
# 8            Nvidia GeForce MX150    Windows 10    1.3kg      1495.00
# 13             AMD Radeon R5 M430    Windows 10    2.2kg       498.90
# 18           Nvidia GeForce 940MX         No OS    2.2kg       499.00
# 30              Intel HD Graphics    Windows 10   1.89kg       244.99
# 58        Nvidia GeForce GTX 1070    Windows 10   2.43kg      2449.00
# 70          Intel HD Graphics 620  Windows 10 S  1.252kg      1089.00
# 143         Intel HD Graphics 520    Windows 10    2.1kg       602.00
# 170         Intel HD Graphics 620    Windows 10   1.05kg      1349.00
# 184          Nvidia GeForce MX150         No OS   1.95kg      1199.00
# 191         Intel HD Graphics 500    Windows 10    1.3kg       260.00
# 196       Nvidia GeForce GTX 1080    Windows 10   3.49kg      6099.00
# 429         Intel HD Graphics 500    Windows 10   1.16kg       299.00
# 430         Intel HD Graphics 400     Chrome OS   1.15kg       269.00
# 437         Intel HD Graphics 615     Chrome OS    1.1kg      2199.00
# 567         Intel HD Graphics 620    Windows 10    2.2kg       739.00
# 678         Intel HD Graphics 620    Windows 10   1.09kg      2299.00

# %%
df_laptops.drop_duplicates(['Company'])[['Company','Price_euros']]
# Out:
#        Company  Price_euros
# 0        Apple      1339.69
# 2           HP       575.00
# 5         Acer       400.00
# 8         Asus      1495.00
# 13        Dell       498.90
# 18      Lenovo       499.00
# 30       Chuwi       244.99
# 58         MSI      2449.00
# 70   Microsoft      1089.00
# 143    Toshiba       602.00
# 170     Huawei      1349.00
# 184     Xiaomi      1199.00
# 191       Vero       260.00
# 196      Razer      6099.00
# 429   Mediacom       299.00
# 430    Samsung       269.00
# 437     Google      2199.00
# 567    Fujitsu       739.00
# 678         LG      2299.00

# %%
df_laptops.drop_duplicates(['Company'])[['Company','Price_euros']].value_counts()
# Out:
# Company    Price_euros
# Acer       400.00         1
# Apple      1339.69        1
# Asus       1495.00        1
# Chuwi      244.99         1
# Dell       498.90         1
# Fujitsu    739.00         1
# Google     2199.00        1
# HP         575.00         1
# Huawei     1349.00        1
# LG         2299.00        1
# Lenovo     499.00         1
# MSI        2449.00        1
# Mediacom   299.00         1
# Microsoft  1089.00        1
# Razer      6099.00        1
# Samsung    269.00         1
# Toshiba    602.00         1
# Vero       260.00         1
# Xiaomi     1199.00        1
# Name: count, dtype: int64

# %%
df_laptops = df_laptops.sort_values(['Company','Price_euros'])

# %%
df_laptops.drop_duplicates(['Company'],keep = 'first')[['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
df_laptops.drop_duplicates(['Company'],keep='last',inplace  = True,ignore_index=True)

# %%
df_laptops
# Out:
#     laptop_ID    Company                        Product     TypeName  Inches  \
# 0        1207       Acer                Predator G9-793       Gaming    17.3
# 1          18      Apple                    MacBook Pro    Ultrabook    15.4
# 2        1081       Asus                     ROG G701VO       Gaming    17.3
# 3         428      Chuwi                   LapBook 12.3     Notebook    12.3
# 4         731       Dell                   Alienware 17       Gaming    17.3
# 5         630    Fujitsu                  LifeBook A557     Notebook    15.6
# 6         444     Google                Pixelbook (Core    Ultrabook    12.3
# 7         758         HP                       Zbook 17  Workstation    17.3
# 8         219     Huawei                     MateBook X    Ultrabook    13.0
# 9         686         LG                    Gram 15Z975    Ultrabook    15.6
# 10        617     Lenovo                   Thinkpad P51     Notebook    15.6
# 11        181        MSI                GT80S 6QF-074US       Gaming    18.4
# 12        587   Mediacom                 SmartBook Edge     Notebook    14.0
# 13        456  Microsoft                 Surface Laptop    Ultrabook    13.5
# 14        200      Razer                      Blade Pro       Gaming    17.3
# 15        885    Samsung                     Notebook 9    Ultrabook    15.0
# 16        498    Toshiba              Portege X30-D-10L    Ultrabook    13.3
# 17        195       Vero  K147 (N3350/4GB/32GB/FHD/W10)     Notebook    14.0
# 18        521     Xiaomi                    Mi Notebook     Notebook    15.6
#
#                        ScreenResolution                                   Cpu  \
# 0           IPS Panel Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz
# 1    IPS Panel Retina Display 2880x1800                  Intel Core i7 2.9GHz
# 2           IPS Panel Full HD 1920x1080           Intel Core i7 6820HK 2.7GHz
# 3    IPS Panel Retina Display 2736x1824  Intel Celeron Quad Core N3450 1.1GHz
# 4                 4K Ultra HD 3840x2160           Intel Core i7 7700HQ 2.8GHz
# 5                              1366x768            Intel Core i5 7200U 2.5GHz
# 6                 Touchscreen 2400x1600             Intel Core i7 7Y75 1.3GHz
# 7           IPS Panel Full HD 1920x1080         Intel Xeon E3-1535M v5 2.9GHz
# 8           IPS Panel Full HD 2160x1440            Intel Core i7 7500U 2.7GHz
# 9           IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz
# 10      IPS Panel 4K Ultra HD 3840x2160         Intel Xeon E3-1535M v6 3.1GHz
# 11                    Full HD 1920x1080           Intel Core i7 6920HQ 2.9GHz
# 12          IPS Panel Full HD 1920x1080  Intel Celeron Quad Core N3450 1.1GHz
# 13                Touchscreen 2256x1504            Intel Core i7 7660U 2.5GHz
# 14  4K Ultra HD / Touchscreen 3840x2160           Intel Core i7 7820HK 2.9GHz
# 15                    Full HD 1920x1080            Intel Core i7 7500U 2.7GHz
# 16      Full HD / Touchscreen 1920x1080            Intel Core i7 7500U 2.7GHz
# 17          IPS Panel Full HD 1920x1080  Intel Celeron Dual Core N3350 1.1GHz
# 18          IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz
#
#      Ram                Memory                           Gpu         OpSys  \
# 0   16GB  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1070    Windows 10
# 1   16GB             512GB SSD            AMD Radeon Pro 560         macOS
# 2   64GB               1TB SSD       Nvidia GeForce GTX 980     Windows 10
# 3    6GB    64GB Flash Storage         Intel HD Graphics 500    Windows 10
# 4   32GB    1TB SSD +  1TB HDD       Nvidia GeForce GTX 1070    Windows 10
# 5    8GB             256GB SSD         Intel HD Graphics 620    Windows 10
# 6   16GB             512GB SSD         Intel HD Graphics 615     Chrome OS
# 7   16GB             256GB SSD          Nvidia Quadro M2000M     Windows 7
# 8    8GB             512GB SSD         Intel HD Graphics 620    Windows 10
# 9    8GB             512GB SSD         Intel HD Graphics 620    Windows 10
# 10  32GB               1TB SSD          Nvidia Quadro M2200M    Windows 10
# 11  32GB  512GB SSD +  1TB HDD            Nvidia GTX 980 SLI    Windows 10
# 12   4GB              32GB SSD         Intel HD Graphics 500    Windows 10
# 13  16GB             512GB SSD  Intel Iris Plus Graphics 640  Windows 10 S
# 14  32GB               1TB SSD       Nvidia GeForce GTX 1080    Windows 10
# 15  16GB             256GB SSD          Nvidia GeForce 940MX    Windows 10
# 16  32GB             512GB SSD         Intel HD Graphics 620    Windows 10
# 17   4GB    32GB Flash Storage         Intel HD Graphics 500    Windows 10
# 18  16GB             256GB SSD          Nvidia GeForce MX150         No OS
#
#     Weight  Price_euros
# 0    4.2kg      2599.00
# 1   1.83kg      2858.00
# 2   3.58kg      3975.00
# 3    1.4kg       449.00
# 4   4.36kg      3659.40
# 5    2.2kg       799.00
# 6    1.1kg      2199.00
# 7      3kg      4389.00
# 8   1.05kg      1499.00
# 9   1.09kg      2299.00
# 10   2.5kg      4899.00
# 11   4.4kg      2799.00
# 12  1.45kg       389.00
# 13  1.25kg      2589.00
# 14  3.49kg      6099.00
# 15  1.23kg      1849.00
# 16  1.05kg      2799.00
# 17   1.3kg       260.00
# 18  1.95kg      1399.95

# %%
df_laptops = df_laptops[['Company','Price_euros']]

# %% [markdown]
# ## Exercises

# %%
df_laptops = pd.read_csv('laptop_price.csv',encoding='ISO-8859-1')

# %%
df_laptops = df_laptops.sort_values(['Company','Inches'])

# %%
df_laptops
# Out:
#       laptop_ID Company                               Product  \
# 319         324    Acer                          TravelMate B
# 461         468    Acer                          TravelMate B
# 560         567    Acer                         Spin SP111-31
# 619         626    Acer  CB5-132T-C9KK (N3160/4GB/32GB/Chrome
# 695         703    Acer                     TravelMate B117-M
# ...         ...     ...                                   ...
# 1041       1055    Vero          V142 (X5-Z8350/2GB/32GB/W10)
# 192         196  Xiaomi                           Mi Notebook
# 877         888  Xiaomi                           Mi Notebook
# 184         188  Xiaomi                           Mi Notebook
# 514         521  Xiaomi                           Mi Notebook
#
#                 TypeName  Inches                           ScreenResolution  \
# 319             Notebook    11.6                                   1366x768
# 461              Netbook    11.6                                   1366x768
# 560   2 in 1 Convertible    11.6  IPS Panel Full HD / Touchscreen 1920x1080
# 619   2 in 1 Convertible    11.6             IPS Panel Touchscreen 1366x768
# 695              Netbook    11.6                                   1366x768
# ...                  ...     ...                                        ...
# 1041            Notebook    14.0                                   1366x768
# 192            Ultrabook    13.3                IPS Panel Full HD 1920x1080
# 877            Ultrabook    13.3                IPS Panel Full HD 1920x1080
# 184             Notebook    15.6                IPS Panel Full HD 1920x1080
# 514             Notebook    15.6                IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram               Memory  \
# 319   Intel Pentium Quad Core N3710 1.6GHz   4GB  128GB Flash Storage
# 461   Intel Celeron Dual Core N3060 1.6GHz   4GB            128GB SSD
# 560   Intel Celeron Dual Core N3350 2.0GHz   4GB   32GB Flash Storage
# 619   Intel Celeron Quad Core N3160 1.6GHz   4GB   32GB Flash Storage
# 695   Intel Celeron Dual Core N3050 1.6GHz   4GB   32GB Flash Storage
# ...                                    ...   ...                  ...
# 1041           Intel Atom X5-Z8350 1.44GHz   2GB   32GB Flash Storage
# 192             Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 877             Intel Core i5 6200U 2.3GHz   8GB            256GB SSD
# 184             Intel Core i5 8250U 1.6GHz   8GB            256GB SSD
# 514             Intel Core i7 8550U 1.8GHz  16GB            256GB SSD
#
#                         Gpu       OpSys  Weight  Price_euros
# 319   Intel HD Graphics 405  Windows 10   1.4kg       485.00
# 461   Intel HD Graphics 400  Windows 10   1.4kg       435.00
# 560   Intel HD Graphics 500  Windows 10  1.25kg       349.00
# 619   Intel HD Graphics 400   Chrome OS  1.25kg       379.00
# 695       Intel HD Graphics  Windows 10   1.4kg       269.00
# ...                     ...         ...     ...          ...
# 1041  Intel HD Graphics 400  Windows 10  1.45kg       210.80
# 192    Nvidia GeForce MX150       No OS   1.3kg       999.90
# 877    Nvidia GeForce 940MX  Windows 10  1.28kg       935.00
# 184    Nvidia GeForce MX150       No OS  1.95kg      1199.00
# 514    Nvidia GeForce MX150       No OS  1.95kg      1399.95
#
# [1303 rows x 13 columns]

# %%
df_laptops.drop_duplicates(['Company'],keep='first')[['Company','Inches']]
# Out:
#         Company  Inches
# 319        Acer    11.6
# 1234      Apple    11.6
# 20         Asus    11.6
# 421       Chuwi    12.3
# 455        Dell    11.6
# 567     Fujitsu    15.6
# 437      Google    12.3
# 677          HP    11.6
# 170      Huawei    13.0
# 909          LG    14.0
# 50       Lenovo    10.1
# 785         MSI    14.0
# 429    Mediacom    11.6
# 70    Microsoft    13.5
# 816       Razer    12.5
# 430     Samsung    11.6
# 963     Toshiba    12.5
# 1120       Vero    13.3
# 192      Xiaomi    13.3

# %%
df_laptops.drop_duplicates(['Company'],keep='last')[['Company','Inches']]
# Out:
#         Company  Inches
# 1216       Acer    17.3
# 17        Apple    15.4
# 1256       Asus    17.3
# 483       Chuwi    15.6
# 1243       Dell    17.3
# 983     Fujitsu    15.6
# 762      Google    12.3
# 1136         HP    17.3
# 214      Huawei    13.0
# 905          LG    15.6
# 1217     Lenovo    17.3
# 177         MSI    18.4
# 718    Mediacom    14.0
# 670   Microsoft    13.5
# 830       Razer    17.3
# 593     Samsung    15.6
# 1042    Toshiba    15.6
# 1041       Vero    14.0
# 514      Xiaomi    15.6

# %% [markdown]
# ## unique()

# %%
df_laptops = pd.read_csv('laptop_price.csv',encoding = 'ISO-8859-1')

# %%
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
df_laptops['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df_laptops['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
len(df_laptops['Inches'].unique())
# Out:
# 18

# %%
len(df_laptops['Company'].unique())
# Out:
# 19

# %% [markdown]
# ## nunique()

# %%
df_laptops['Company'].nunique()
# Out:
# 19

# %%
df_laptops['Inches'].nunique()
# Out:
# 18
